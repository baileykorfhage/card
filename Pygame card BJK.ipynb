# %%
import pygame
pygame.init()
from math import pi
from pygame import mixer

pygame.display.set_caption('Merry Christmas from our family to yours')


white=(255,255,255)
black=(0,0,0)
dred=(179,0,12)
dgreen=(13,89,1)
green=(0,179,44)
yellow=(255,255,0)
blue=(0,0,220)
red=(255,25,42)

surface=pygame.display.set_mode((500,600))
surface.fill(white)
pygame.display.flip()

pygame.draw.ellipse(surface, dgreen, pygame.Rect(30,500,240,60))
pygame.draw.ellipse(surface, dgreen, pygame.Rect(40,475,220,55))
pygame.draw.ellipse(surface, dgreen, pygame.Rect(50,450,200,50))
pygame.draw.ellipse(surface, dgreen, pygame.Rect(60,427,180,45))
pygame.draw.ellipse(surface, dgreen, pygame.Rect(70,405,160,40))
pygame.draw.ellipse(surface, dgreen, pygame.Rect(80,387,140,35))
pygame.draw.ellipse(surface, dgreen, pygame.Rect(90,370,120,30))
pygame.draw.ellipse(surface, dgreen, pygame.Rect(100,355,100,25))
pygame.draw.ellipse(surface, dgreen, pygame.Rect(110,342,80,20))
pygame.draw.ellipse(surface, dgreen, pygame.Rect(120,332,60,15))
pygame.draw.ellipse(surface, dgreen, pygame.Rect(130,325,40,10))

pygame.draw.ellipse(surface, yellow, pygame.Rect(170,400,5,10))
pygame.draw.ellipse(surface, yellow, pygame.Rect(80,450,5,10))
pygame.draw.ellipse(surface, yellow, pygame.Rect(125,475,5,10))
pygame.draw.ellipse(surface, yellow, pygame.Rect(70,510,5,10))
pygame.draw.ellipse(surface, yellow, pygame.Rect(120,415,5,10))
pygame.draw.ellipse(surface, yellow, pygame.Rect(210,500,5,10))
pygame.draw.ellipse(surface, yellow, pygame.Rect(190,450,5,10))
pygame.draw.ellipse(surface, yellow, pygame.Rect(135,350,5,10))
pygame.draw.ellipse(surface, yellow, pygame.Rect(160,500,5,10))

pygame.draw.ellipse(surface, blue, pygame.Rect(70,475,5,10))
pygame.draw.ellipse(surface, blue, pygame.Rect(180,475,5,10))
pygame.draw.ellipse(surface, blue, pygame.Rect(150,420,5,10))
pygame.draw.ellipse(surface, blue, pygame.Rect(120,380,5,10))
pygame.draw.ellipse(surface, blue, pygame.Rect(110,525,5,10))
pygame.draw.ellipse(surface, blue, pygame.Rect(170,370,5,10))
pygame.draw.ellipse(surface, blue, pygame.Rect(230,520,5,10))

pygame.draw.ellipse(surface, red, pygame.Rect(150,525,5,10))
pygame.draw.ellipse(surface, red, pygame.Rect(145,385,5,10))
pygame.draw.ellipse(surface, red, pygame.Rect(100,410,5,10))
pygame.draw.ellipse(surface, red, pygame.Rect(200,420,5,10))
pygame.draw.ellipse(surface, red, pygame.Rect(140,450,5,10))
pygame.draw.ellipse(surface, red, pygame.Rect(95,475,5,10))
pygame.draw.ellipse(surface, red, pygame.Rect(220,465,5,10))

pygame.draw.ellipse(surface, green, pygame.Rect(160,345,5,10))
pygame.draw.ellipse(surface, green, pygame.Rect(115,445,5,10))
pygame.draw.ellipse(surface, green, pygame.Rect(175,430,5,10))
pygame.draw.ellipse(surface, green, pygame.Rect(160,465,5,10))
pygame.draw.ellipse(surface, green, pygame.Rect(185,535,5,10))
pygame.draw.ellipse(surface, green, pygame.Rect(105,500,5,10))

points=[(150,305),(145,315),(135,315),(143,320),(140,330),(150,323),(160,330),(157,320),(165,315),(155,315)]
pygame.draw.polygon(surface,yellow,points)
pygame.display.flip()

img=pygame.image.load('family.jfif').convert()

resized_image=pygame.transform.scale(img,(250,175))

x=250 #coordinate of the image
y=250

surface.blit(resized_image, (x,y))

pygame.display.flip()

font=pygame.font.Font('freesansbold.ttf',48)
font1=pygame.font.Font('freesansbold.ttf',24)
text=font.render('Merry Christmas', True, dred)
text1=font1.render('FROM OUR FAMILY TO YOURS',True,dred)
textRect=text.get_rect()
textRect1=text.get_rect()
X1=535
Y2=350
X=500
Y=250
textRect.center=(X//2, Y//2)
textRect1.center=(X1//2, Y2//2)

surface.blit(text,textRect)
surface.blit(text1,textRect1)

pygame.display.flip()

mixer.init()

mixer.music.load('jingle bells.mp3')

mixer.music.set_volume(0.7)

#start playing the song
mixer.music.play()

while True:
    print('Press p to pause, r to resume, e to exit')
    query=input(' ')
    
    if query=='p':
        mixer.music.pause()
    elif query=='r':
        mixer.music.unpause()
    elif query=='e':
        mixer.music.stop()
        break
        
active=True
while active:
    for event in pygame.event.get():
        if event.type==pygame.QUIT:
            active=False
        pygame.display.update()
        
pygame.quit()
# Out:
# Press p to pause, r to resume, e to exit
#  e
